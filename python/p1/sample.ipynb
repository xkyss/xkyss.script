# %%
from util import tt
import util as u

# %%
import subprocess

# %%
subprocess.run("dir", shell=True)
# Out:
# CompletedProcess(args='dir', returncode=0)

# %%
tt()
u.tt()
# Out:
# hello world
# hello world
